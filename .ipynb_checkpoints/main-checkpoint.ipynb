# %%
print('hello world')
# Out:
# hello world

# %%
1+2
# Out:
# 3

# %%
29 % 10
# Out:
# 9

# %%
19 % 18
# Out:
# 1

# %%
18 % 13
# Out:
# 5

# %%
2.6 * 3
# Out:
# 7.800000000000001

# %%
2.6 ** 3
# Out:
# 17.576

# %%
9 ** 8
# Out:
# 43046721

# %%
9 ** 2
# Out:
# 81

# %%
123 / 120
# Out:
# 1.025

# %%
print('alyo')
# Out:
# alyo

# %%
print("alyo")
# Out:
# alyo

# %%
'alyo' == "alyo"
# Out:
# True

# %%
'alyo' == "alyoo"
# Out:
# False

# %%
print(type(1))
# Out:
# <class 'int'>

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
False + True
# Out:
# 1

# %%
isinstance(456, int)
# Out:
# True

# %%
"qwe" + "rty"
# Out:
# 'qwerty'

# %%
elyor_kak_dela = "privet"

# %%
elyor_kak_dela
# Out:
# 'privet'

# %%
print(elyor_kak_dela)
# Out:
# privet

# %%
type(elyor_kak_dela)
# Out:
# str

# %%
elyor_kak_dela[1:len(elyor_kak_dela)]
# Out:
# 'rivet'

# %%
len(elyor_kak_dela)
# Out:
# 6

# %%
bla = 3

# %%
if bla > 2:
    print("реально он больше")
# Out:
# реально он больше

# %%
if bla > 2:
    print("реально он больше")
# Out:
# реально он больше

# %%
if bla > 4:
    print("реально он больше")

# %%
False == 0
# Out:
# True

# %%
True == 0
# Out:
# False

# %%
if '7':
    print('это не цифры')
# Out:
# это не цифры

# %%
if '':
    print('это не цифры')

# %%
if 0:
    print('это не цифры')

# %%
if 1:
    print('это не цифры')
# Out:
# это не цифры

# %%
print('hello world')
# Out:
# hello world

# %%
'dok' + 'oki'
# Out:
# 'dokoki'

# %%
"dok" + 'oli'
# Out:
# 'dokoli'

# %%
elyor = ("you wassap", 20, 10)

# %%
print(elyor)
# Out:
# ('you wassap', 20, 10)

# %%
clas = ['qwe', 'rty', 'uio']

# %%
print(clas)
# Out:
# ['qwe', 'rty', 'uio']

# %%
clas.append('ooo')

# %%
print(clas)
# Out:
# ['qwe', 'rty', 'uio', 'ooo']

# %%
id(clas)
# Out:
# 1730345175872

# %%
clas.pop()
# Out:
# 'ooo'

# %%
print(clas)
# Out:
# ['qwe', 'rty', 'uio']

# %%
clas[1] = 'wattafa'

# %%
print(clas)
# Out:
# ['qwe', 'wattafa', 'uio']

# %%
elyor_klyuch = {
    2: "realnyo",
    4: "prikin",
}

# %%
print(elyor_klyuch)
# Out:
# {2: 'realnyo', 4: 'prikin'}

# %%
elyor_klyuch['qoqoq'] = 3

# %%
elyor_klyuch
# Out:
# {2: 'realnyo', 4: 'prikin', 'qoqoq': 3}

# %%
my_dict = {
    (): "a gde",
    1: "tut",
}

# %%
my_dict["my dict"] = 7

# %%
my_dict
# Out:
# {(): 'a gde', 1: 'tut', 'my dict': 7}

# %%
my_dict
# Out:
# {(): 'a gde', 1: 'tut', 'my dict': 7}

# %%
my_dict[1]
# Out:
# 'tut'

# %%
my_dict[1]
# Out:
# 'tut'

# %%
"lll" in "hello"
# Out:
# False

# %%
clear

# %%
list = (1, 2, 3, 4, 5)

# %%
list
# Out:
# (1, 2, 3, 4, 5)

# %%
list = [1, 2, 3, 4, 5]

# %% [raw]
# list

# %%
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
list[0] = 100

# %%
list
# Out:
# [100, 2, 3, 4, 5]

# %%
list.append(999)

# %%
list
# Out:
# [100, 2, 3, 4, 5, 999]

# %%
list.pop(5)
# Out:
# 999

# %%
my_tuple = ('abc', 'qwe', 'vas')

# %% [raw]
# print(my_tuple)

# %%
print(my_tuple)
# Out:
# ('abc', 'qwe', 'vas')

# %%
my_dictt = {
    "name": 'elyor',
    "age": '19',
    "city": 'Tashkent',
}

# %%
print(my_dictt)
# Out:
# {'name': 'elyor', 'age': '19', 'city': 'Tashkent'}

# %%
my_dictt['name']
# Out:
# 'elyor'

# %%
my_dictt['age'] = '20'

# %%
print(my_dictt)
# Out:
# {'name': 'elyor', 'age': '20', 'city': 'Tashkent'}

# %%
my_dictt['job'] = 4

# %%
print(my_dictt)
# Out:
# {'name': 'elyor', 'age': '20', 'city': 'Tashkent', 'job': 4}

# %%
my_set = {1, 1, 2, 2, 3, 3, 4}

# %%
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
numbers = [1, 1, 2, 2, 3, 4, 4, 5]

# %%
numbers = list

# %%
print(numbers)
# Out:
# [100, 2, 3, 4, 5]

# %%
x = 1
if x < 0:
    print("отрицательное")
elif x == 0:
    print("ноль")
elif x 
    print("положительное")
# Out:
# положительное

# %%
x = 99
if x < 10:
    print("маленькое")
elif x >= 99:
    print("среднее")
else:
    print("больше")
# Out:
# среднее

# %%
x = 0

if x == 0:
    print('ноль')
elif x == 1:
    print("один")
else:
    print("другое")
# Out:
# ноль

# %%
s = 'admin'
if s == "adminn":
    print("доступ полный")
elif s == 'user':
    print("доступ ограничен")
else:
    print("неизвестный пользователь")
# Out:
# неизвестный пользователь

# %%
x = 15
if x > 10:
    print("больше десяти")
elif x > 0:
    print("положительное")
else:
    print("другое")
# Out:
# больше десяти

# %%
s = "hello"
if len(s) == 0:
    print("пустая строка")
elif len(s) < 6:
    print("короткая")
else:
    print("длинная")
# Out:
# короткая

# %%
len("hi")
# Out:
# 2

# %%
len(" ")
# Out:
# 1

# %%
x = 25
if x < 0:
    print("меньше 0")
elif 0 <= x <= 10:
    print("от 0 до 10")
elif x == 11 >= 20:
    print("от 11 до 20")
elif x > 20:
    print("больше 20")
# Out:
# больше 20

# %%
s = "no"
if s == "yes":
    print("подтверждено")
elif s == "no":
    print("отклонено")
else:
    print("непонятный ответ")
# Out:
# отклонено

# %%
password = "admin123"
if password == "":
    print("пароль пустой")
elif len(password) < 6:
    print("слишком короткий")
elif password == "admin123":
    print("доступ разрешён")
else:
    print("неверный пароль")
# Out:
# доступ разрешён

# %%
login = "admin"
password = "12345"
if len(login) == 0:
    print("логин пуст")
elif len(password) == 0:
    print("пароль же пуст")
elif len(password) < 6:
    print("слишком короткий пароль")
elif login == "admin" and password == "admin123":
    print("доступ разрешен")
else:
    print("неверные данные")
# Out:
# слишком короткий пароль

# %%
age = 17
has_passport = True
is_student = False
if  has_passport:
    print("доступ разрешён")
elif is_student:
    print("доступ ограничен")
else:
    print("доступ запрещён")
# Out:
# доступ разрешён
